# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/user123454321/kits19-1/case_00091/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00091/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00046/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00046/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00057/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00057/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00083/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00083/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00077/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00077/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00027/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00027/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00005/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00005/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00059/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00059/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00063/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00063/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00054/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00054/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00051/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00051/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00009/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00009/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00015/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00015/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00048/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00048/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00055/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00055/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00041/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00041/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00006/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00006/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00061/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00061/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00064/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00064/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00089/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00089/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00010/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00010/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00066/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00066/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00050/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00050/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00087/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00087/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00033/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00033/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00036/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00036/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00072/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00072/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00097/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00097/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00011/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00011/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00071/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00071/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00008/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00008/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00014/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00014/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00047/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00047/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00096/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00096/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00068/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00068/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00021/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00021/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00085/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00085/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00078/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00078/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00093/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00093/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00073/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00073/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00002/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00002/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00075/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00075/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00060/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00060/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00026/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00026/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00099/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00099/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00013/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00013/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00019/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00019/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00043/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00043/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00032/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00032/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00017/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00017/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00086/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00086/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00053/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00053/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00080/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00080/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00094/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00094/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00037/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00037/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00031/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00031/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00004/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00004/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00016/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00016/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00035/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00035/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00034/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00034/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00028/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00028/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00082/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00082/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00049/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00049/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00062/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00062/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00098/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00098/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00040/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00040/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00067/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00067/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00088/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00088/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00056/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00056/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00022/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00022/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00018/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00018/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00084/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00084/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00025/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00025/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00003/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00003/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00007/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00007/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00076/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00076/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00095/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00095/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00042/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00042/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00090/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00090/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00070/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00070/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00045/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00045/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00065/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00065/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00081/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00081/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00079/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00079/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00000/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00000/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00001/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00001/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00020/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00020/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00012/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00012/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00074/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00074/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00058/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00058/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00024/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00024/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00039/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00039/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00052/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00052/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00023/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00023/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00044/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00044/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00092/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00092/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00069/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00069/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00030/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00030/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00029/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00029/segmentation.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00038/imaging.nii
# /kaggle/input/datasets/user123454321/kits19-1/case_00038/segmentation.nii

# %%
# %% ========================= 模块1 Environment =========================
import os
import glob
import random
from functools import lru_cache
import torch.nn as nn
 
import numpy as np
import nibabel as nib          # 若Kaggle环境未预装，取消下一行注释安装
# !pip install nibabel
 
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
 
 
def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
 
 
SEED = 42
set_seed(SEED)
 
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"使用设备: {DEVICE}")
if torch.cuda.is_available():
    print(f"GPU型号: {torch.cuda.get_device_name(0)}")
 
DATA_ROOT = "/kaggle/input/datasets/user123454321/kits19-1"
OUTPUT_DIR = "/kaggle/working"
os.makedirs(OUTPUT_DIR, exist_ok=True)
# Out:
# 使用设备: cuda
# GPU型号: Tesla T4

# %%
# %% ========================= 模块2 Config =========================
class Config:
    # 数据路径
    DATA_ROOT = DATA_ROOT
    OUTPUT_DIR = OUTPUT_DIR
 
    # 数据集划分比例（按病例划分，避免同一病例的切片同时出现在train/val/test）
    TRAIN_RATIO = 0.70
    VAL_RATIO = 0.15
    TEST_RATIO = 0.15
 
    # 图像与标签
    IMG_SIZE = 256
    NUM_CLASSES = 3          # 0=背景, 1=肾脏, 2=肿瘤
    HU_MIN = -200            # CT窗宽窗位裁剪下界
    HU_MAX = 300              # CT窗宽窗位裁剪上界
 
    # 训练超参数
    BATCH_SIZE = 8
    LEARNING_RATE = 1e-4
    EPOCHS = 50
 
    # 预留给后续贝叶斯/不确定性模块，基础U-Net阶段暂不使用
    DROPOUT_RATE = 0.0
    UNCERTAINTY_THRESHOLD = None
 
    SEED = SEED
    DEVICE = DEVICE
 
 
cfg = Config()

# %%
# %% ========================= 模块3 Dataset =========================
def scan_valid_cases(data_root: str):
    """扫描data_root下所有case_*目录，保留同时具有imaging.nii和segmentation.nii的病例"""
    case_dirs = sorted(glob.glob(os.path.join(data_root, "case_*")))
    valid_cases = [
        c for c in case_dirs
        if os.path.isfile(os.path.join(c, "imaging.nii"))
        and os.path.isfile(os.path.join(c, "segmentation.nii"))
    ]
    print(f"数据集扫描完成: 共 {len(valid_cases)} 个有效病例（来自 {len(case_dirs)} 个目录）")
    return valid_cases
 
 
class KiTS19SliceDataset(Dataset):
    """
    从KiTS19病例的3D CT体积中提取2D轴向切片（假定数组形状为 [切片数, H, W]）。
    只保留含有肾脏(1)或肿瘤(2)标注的切片，过滤纯背景切片。
 
    初始化时一次性读盘、完成窗宽窗位归一化与resize，并把结果常驻内存；
    __getitem__ 只从内存取数据，不再重复读盘。
    （此前每次__getitem__现读整卷CT、缓存位只有4个，在shuffle训练下几乎每张切片
    都要重新读一次约1.2GB的体数据，是导致训练卡住不动的根本原因，这里做了修正）
    """
 
    def __init__(self, case_dirs, img_size, hu_min, hu_max, transform=None):
        self.img_size = img_size
        self.transform = transform
        self.images = []  # 每个元素: (img_size, img_size) float32
        self.masks = []   # 每个元素: (img_size, img_size) int64
        self._preload(case_dirs, hu_min, hu_max)
 
    def _preload(self, case_dirs, hu_min, hu_max):
        for case_dir in case_dirs:
            img_vol = nib.load(os.path.join(case_dir, "imaging.nii")).get_fdata()
            seg_vol = nib.load(os.path.join(case_dir, "segmentation.nii")).get_fdata()
            nonempty_idx = np.where(seg_vol.sum(axis=(1, 2)) > 0)[0]
 
            for idx in nonempty_idx:
                img = img_vol[idx, :, :].astype(np.float32)
                mask = seg_vol[idx, :, :].astype(np.int64)
 
                img = np.clip(img, hu_min, hu_max)
                img = (img - hu_min) / (hu_max - hu_min)
 
                img_t = torch.from_numpy(img).unsqueeze(0).unsqueeze(0)
                mask_t = torch.from_numpy(mask).unsqueeze(0).unsqueeze(0).float()
 
                img_t = F.interpolate(img_t, size=(self.img_size, self.img_size),
                                       mode="bilinear", align_corners=False)
                mask_t = F.interpolate(mask_t, size=(self.img_size, self.img_size), mode="nearest")
 
                self.images.append(img_t.squeeze(0).squeeze(0).numpy().astype(np.float32))
                self.masks.append(mask_t.squeeze(0).squeeze(0).numpy().astype(np.int64))
 
        print(f"切片预加载完成: 共 {len(self.images)} 个有效切片（已过滤纯背景切片，已常驻内存）")
 
    def __len__(self):
        return len(self.images)
 
    def __getitem__(self, i):
        img_t = torch.from_numpy(self.images[i]).unsqueeze(0)  # (1, H, W)
        mask_t = torch.from_numpy(self.masks[i])                # (H, W)
 
        if self.transform is not None:
            img_t, mask_t = self.transform(img_t, mask_t)
 
        return img_t, mask_t

# %%
# %% ========================= 模块4 DataLoader =========================
def split_cases(case_dirs, train_ratio, val_ratio, seed):
    """按病例（而非切片）划分train/val/test，避免同一病例的切片跨集合造成数据泄漏"""
    rng = random.Random(seed)
    cases = case_dirs.copy()
    rng.shuffle(cases)
    n = len(cases)
    n_train = int(n * train_ratio)
    n_val = int(n * val_ratio)
    train_cases = cases[:n_train]
    val_cases = cases[n_train:n_train + n_val]
    test_cases = cases[n_train + n_val:]
    return train_cases, val_cases, test_cases
 
 
all_cases = scan_valid_cases(cfg.DATA_ROOT)
train_cases, val_cases, test_cases = split_cases(
    all_cases, cfg.TRAIN_RATIO, cfg.VAL_RATIO, cfg.SEED
)
 
# 此处先不带增强构建数据集，训练集的增强由模块5单独挂载
train_dataset = KiTS19SliceDataset(train_cases, cfg.IMG_SIZE, cfg.HU_MIN, cfg.HU_MAX, transform=None)
val_dataset = KiTS19SliceDataset(val_cases, cfg.IMG_SIZE, cfg.HU_MIN, cfg.HU_MAX, transform=None)
test_dataset = KiTS19SliceDataset(test_cases, cfg.IMG_SIZE, cfg.HU_MIN, cfg.HU_MAX, transform=None)
 
train_loader = DataLoader(train_dataset, batch_size=cfg.BATCH_SIZE, shuffle=True,
                           num_workers=2, drop_last=True)
val_loader = DataLoader(val_dataset, batch_size=cfg.BATCH_SIZE, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=cfg.BATCH_SIZE, shuffle=False, num_workers=2)
 
print("=" * 50)
print("数据加载器统计")
print("=" * 50)
print(f"批次大小: {cfg.BATCH_SIZE}")
print(f"训练批次数: {len(train_loader)}")
print(f"验证批次数: {len(val_loader)}")
print(f"测试批次数: {len(test_loader)}")
print(f"总批次数: {len(train_loader) + len(val_loader) + len(test_loader)}")
print("=" * 50)
print(f"训练集病例数: {len(train_cases)} | 验证集病例数: {len(val_cases)} | 测试集病例数: {len(test_cases)}")
# Out:
# 数据集扫描完成: 共 100 个有效病例（来自 100 个目录）
# 切片预加载完成: 共 5444 个有效切片（已过滤纯背景切片，已常驻内存）
# 切片预加载完成: 共 1636 个有效切片（已过滤纯背景切片，已常驻内存）
# 切片预加载完成: 共 685 个有效切片（已过滤纯背景切片，已常驻内存）
# ==================================================
# 数据加载器统计
# ==================================================
# 批次大小: 8
# 训练批次数: 680
# 验证批次数: 205
# 测试批次数: 86
# 总批次数: 971
# ==================================================
# 训练集病例数: 70 | 验证集病例数: 15 | 测试集病例数: 15

# %%
# %% ========================= 模块5 Augmentation =========================
class TrainAugmentation:
    """
    训练阶段增强：随机水平翻转 / 随机垂直翻转 / 随机90度旋转，图像与mask同步变换。
    验证/测试阶段不做随机增强，只保留模块3中已完成的窗宽窗位归一化与resize。
    """
 
    def __call__(self, img, mask):
        if random.random() < 0.5:
            img = torch.flip(img, dims=[-1])
            mask = torch.flip(mask, dims=[-1])
        if random.random() < 0.5:
            img = torch.flip(img, dims=[-2])
            mask = torch.flip(mask, dims=[-2])
        if random.random() < 0.5:
            k = random.choice([1, 2, 3])
            img = torch.rot90(img, k, dims=[-2, -1])
            mask = torch.rot90(mask, k, dims=[-2, -1])
        return img, mask
 
 
train_transform = TrainAugmentation()
train_dataset.transform = train_transform
 
# transform是Dataset的运行时属性，重建train_loader即可让新的transform生效
train_loader = DataLoader(train_dataset, batch_size=cfg.BATCH_SIZE, shuffle=True,
                           num_workers=2, drop_last=True)
 
print("数据增强已启用（仅训练集）: 随机水平翻转 / 随机垂直翻转 / 随机90°旋转")
# Out:
# 数据增强已启用（仅训练集）: 随机水平翻转 / 随机垂直翻转 / 随机90°旋转

# %%
# %% ========================= 模块6 Model =========================
class DoubleConv(nn.Module):
    """(Conv3x3 -> BN -> ReLU) x2"""
 
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
        )
 
    def forward(self, x):
        return self.block(x)
 
 
class UNet(nn.Module):
    """基础U-Net，输入单通道CT切片，输出num_classes通道的分割logits（不含贝叶斯/Dropout采样机制）"""
 
    def __init__(self, in_channels=1, num_classes=3, base_channels=32):
        super().__init__()
        c1, c2, c3, c4, c5 = base_channels, base_channels * 2, base_channels * 4, base_channels * 8, base_channels * 16
 
        self.enc1 = DoubleConv(in_channels, c1)
        self.enc2 = DoubleConv(c1, c2)
        self.enc3 = DoubleConv(c2, c3)
        self.enc4 = DoubleConv(c3, c4)
        self.pool = nn.MaxPool2d(2)
 
        self.bottleneck = DoubleConv(c4, c5)
 
        self.up4 = nn.ConvTranspose2d(c5, c4, kernel_size=2, stride=2)
        self.dec4 = DoubleConv(c5, c4)
        self.up3 = nn.ConvTranspose2d(c4, c3, kernel_size=2, stride=2)
        self.dec3 = DoubleConv(c4, c3)
        self.up2 = nn.ConvTranspose2d(c3, c2, kernel_size=2, stride=2)
        self.dec2 = DoubleConv(c3, c2)
        self.up1 = nn.ConvTranspose2d(c2, c1, kernel_size=2, stride=2)
        self.dec1 = DoubleConv(c2, c1)
 
        self.out_conv = nn.Conv2d(c1, num_classes, kernel_size=1)
 
    def forward(self, x):
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))
 
        b = self.bottleneck(self.pool(e4))
 
        d4 = self.dec4(torch.cat([self.up4(b), e4], dim=1))
        d3 = self.dec3(torch.cat([self.up3(d4), e3], dim=1))
        d2 = self.dec2(torch.cat([self.up2(d3), e2], dim=1))
        d1 = self.dec1(torch.cat([self.up1(d2), e1], dim=1))
 
        return self.out_conv(d1)  # (B, num_classes, H, W) logits
 
 
model = UNet(in_channels=1, num_classes=cfg.NUM_CLASSES, base_channels=32).to(cfg.DEVICE)
n_params = sum(p.numel() for p in model.parameters())
print(f"模型已构建: 基础U-Net | 参数量: {n_params:,}")
# Out:
# 模型已构建: 基础U-Net | 参数量: 7,765,475

# %%
 
# %% ========================= 模块7 Loss & Optimizer =========================
class SoftDiceLoss(nn.Module):
    """多类别可微Dice损失，对logits做softmax后与one-hot标签计算Dice，各类别取平均"""
 
    def __init__(self, num_classes, eps=1e-6):
        super().__init__()
        self.num_classes = num_classes
        self.eps = eps
 
    def forward(self, logits, target):
        probs = torch.softmax(logits, dim=1)
        target_onehot = F.one_hot(target, num_classes=self.num_classes).permute(0, 3, 1, 2).float()
 
        dims = (0, 2, 3)
        intersection = torch.sum(probs * target_onehot, dims)
        union = torch.sum(probs + target_onehot, dims)
        dice_per_class = (2 * intersection + self.eps) / (union + self.eps)
        return 1.0 - dice_per_class.mean()
 
 
class CombinedLoss(nn.Module):
    """CrossEntropy + Dice 组合损失（等权重）。多类别分割用CE替代原方案中的BCE"""
 
    def __init__(self, num_classes):
        super().__init__()
        self.ce = nn.CrossEntropyLoss()
        self.dice = SoftDiceLoss(num_classes)
 
    def forward(self, logits, target):
        return self.ce(logits, target) + self.dice(logits, target)
 
 
criterion = CombinedLoss(cfg.NUM_CLASSES)
optimizer = torch.optim.Adam(model.parameters(), lr=cfg.LEARNING_RATE)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", factor=0.5, patience=5)
 
print(f"损失函数: CrossEntropy + Dice | 优化器: Adam(lr={cfg.LEARNING_RATE}) | 调度器: ReduceLROnPlateau")
# Out:
# 损失函数: CrossEntropy + Dice | 优化器: Adam(lr=0.0001) | 调度器: ReduceLROnPlateau

# %%
# %% ========================= 模块8 Training =========================
def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    for imgs, masks in loader:
        imgs, masks = imgs.to(device), masks.to(device)
 
        optimizer.zero_grad()
        logits = model(imgs)
        loss = criterion(logits, masks)
        loss.backward()
        optimizer.step()
 
        running_loss += loss.item() * imgs.size(0)
 
    return running_loss / len(loader.dataset)

# %%
# %% ========================= 模块9 Validation =========================
def compute_dice_iou(pred, target, num_classes, eps=1e-6):
    """基于argmax硬预测计算各类别Dice和IoU，返回按类别平均值（含背景）"""
    dice_scores, iou_scores = [], []
    for c in range(num_classes):
        pred_c = (pred == c)
        target_c = (target == c)
        intersection = (pred_c & target_c).sum().item()
        pred_sum = pred_c.sum().item()
        target_sum = target_c.sum().item()
        union = pred_sum + target_sum - intersection
 
        if target_sum == 0 and pred_sum == 0:
            dice_scores.append(1.0)
            iou_scores.append(1.0)
        else:
            dice_scores.append((2 * intersection + eps) / (pred_sum + target_sum + eps))
            iou_scores.append((intersection + eps) / (union + eps))
 
    return float(np.mean(dice_scores)), float(np.mean(iou_scores))
 
 
@torch.no_grad()
def evaluate(model, loader, criterion, device, num_classes):
    model.eval()
    running_loss, dice_sum, iou_sum, n_batches = 0.0, 0.0, 0.0, 0
    for imgs, masks in loader:
        imgs, masks = imgs.to(device), masks.to(device)
        logits = model(imgs)
        loss = criterion(logits, masks)
 
        preds = torch.argmax(logits, dim=1)
        dice, iou = compute_dice_iou(preds, masks, num_classes)
 
        running_loss += loss.item() * imgs.size(0)
        dice_sum += dice
        iou_sum += iou
        n_batches += 1
 
    return {
        "loss": running_loss / len(loader.dataset),
        "dice": dice_sum / n_batches,
        "iou": iou_sum / n_batches,
    }
 
 
# ---- 实际执行训练+验证循环（依赖模块8的train_one_epoch与本模块的evaluate）----
history = {"train_loss": [], "val_loss": [], "val_dice": [], "val_iou": []}
best_val_dice = -1.0
best_ckpt_path = os.path.join(cfg.OUTPUT_DIR, "best_unet.pth")
 
print("=" * 50)
print("开始基础U-Net模型训练（不含贝叶斯模块）")
print("=" * 50)
 
for epoch in range(1, cfg.EPOCHS + 1):
    train_loss = train_one_epoch(model, train_loader, criterion, optimizer, cfg.DEVICE)
    val_metrics = evaluate(model, val_loader, criterion, cfg.DEVICE, cfg.NUM_CLASSES)
 
    scheduler.step(val_metrics["loss"])
 
    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_metrics["loss"])
    history["val_dice"].append(val_metrics["dice"])
    history["val_iou"].append(val_metrics["iou"])
 
    print(f"Epoch [{epoch}/{cfg.EPOCHS}] | Train Loss: {train_loss:.4f} | "
          f"Val Loss: {val_metrics['loss']:.4f} | Val Dice: {val_metrics['dice']:.4f} | "
          f"Val IoU: {val_metrics['iou']:.4f}")
 
    if val_metrics["dice"] > best_val_dice:
        best_val_dice = val_metrics["dice"]
        torch.save(model.state_dict(), best_ckpt_path)
        print(f"  -> 保存最优模型 (Val Dice: {best_val_dice:.4f})")
 
print("=" * 50)
print(f"训练完成，最优验证Dice: {best_val_dice:.4f}，模型已保存至: {best_ckpt_path}")
# Out:
# ==================================================
# 开始基础U-Net模型训练（不含贝叶斯模块）
# ==================================================
# Epoch [1/50] | Train Loss: 0.9562 | Val Loss: 0.7285 | Val Dice: 0.7437 | Val IoU: 0.7129
#   -> 保存最优模型 (Val Dice: 0.7437)
# Epoch [2/50] | Train Loss: 0.5260 | Val Loss: 0.4974 | Val Dice: 0.8106 | Val IoU: 0.7885
#   -> 保存最优模型 (Val Dice: 0.8106)
# Epoch [3/50] | Train Loss: 0.3161 | Val Loss: 0.4671 | Val Dice: 0.7842 | Val IoU: 0.7589
# Epoch [4/50] | Train Loss: 0.2298 | Val Loss: 0.3926 | Val Dice: 0.8020 | Val IoU: 0.7748
# Epoch [5/50] | Train Loss: 0.1951 | Val Loss: 0.3928 | Val Dice: 0.8111 | Val IoU: 0.7881
#   -> 保存最优模型 (Val Dice: 0.8111)
# Epoch [6/50] | Train Loss: 0.1758 | Val Loss: 0.3846 | Val Dice: 0.8073 | Val IoU: 0.7799
# Epoch [7/50] | Train Loss: 0.1604 | Val Loss: 0.3768 | Val Dice: 0.8387 | Val IoU: 0.8162
#   -> 保存最优模型 (Val Dice: 0.8387)
# Epoch [8/50] | Train Loss: 0.1533 | Val Loss: 0.3642 | Val Dice: 0.8464 | Val IoU: 0.8238
#   -> 保存最优模型 (Val Dice: 0.8464)
# Epoch [9/50] | Train Loss: 0.1498 | Val Loss: 0.3596 | Val Dice: 0.8474 | Val IoU: 0.8237
#   -> 保存最优模型 (Val Dice: 0.8474)
# Epoch [10/50] | Train Loss: 0.1347 | Val Loss: 0.3967 | Val Dice: 0.8124 | Val IoU: 0.7863
# Epoch [11/50] | Train Loss: 0.1465 | Val Loss: 0.3573 | Val Dice: 0.8341 | Val IoU: 0.8106
# Epoch [12/50] | Train Loss: 0.1301 | Val Loss: 0.3705 | Val Dice: 0.8340 | Val IoU: 0.8121
# Epoch [13/50] | Train Loss: 0.1308 | Val Loss: 0.3697 | Val Dice: 0.8255 | Val IoU: 0.8028
# Epoch [14/50] | Train Loss: 0.1303 | Val Loss: 0.3700 | Val Dice: 0.8435 | Val IoU: 0.8225
# Epoch [15/50] | Train Loss: 0.1219 | Val Loss: 0.3704 | Val Dice: 0.8405 | Val IoU: 0.8183
# Epoch [16/50] | Train Loss: 0.1145 | Val Loss: 0.3637 | Val Dice: 0.8456 | Val IoU: 0.8239
# Epoch [17/50] | Train Loss: 0.1213 | Val Loss: 0.3708 | Val Dice: 0.8345 | Val IoU: 0.8125
# Epoch [18/50] | Train Loss: 0.0991 | Val Loss: 0.3519 | Val Dice: 0.8538 | Val IoU: 0.8325
#   -> 保存最优模型 (Val Dice: 0.8538)
# Epoch [19/50] | Train Loss: 0.1007 | Val Loss: 0.3553 | Val Dice: 0.8494 | Val IoU: 0.8268
# Epoch [20/50] | Train Loss: 0.1008 | Val Loss: 0.3597 | Val Dice: 0.8491 | Val IoU: 0.8278
# Epoch [21/50] | Train Loss: 0.0981 | Val Loss: 0.3476 | Val Dice: 0.8424 | Val IoU: 0.8199
# Epoch [22/50] | Train Loss: 0.0947 | Val Loss: 0.3592 | Val Dice: 0.8308 | Val IoU: 0.8077
# Epoch [23/50] | Train Loss: 0.0953 | Val Loss: 0.3647 | Val Dice: 0.8102 | Val IoU: 0.7875
# Epoch [24/50] | Train Loss: 0.0944 | Val Loss: 0.3494 | Val Dice: 0.8313 | Val IoU: 0.8099
# Epoch [25/50] | Train Loss: 0.0960 | Val Loss: 0.3548 | Val Dice: 0.8447 | Val IoU: 0.8215
# Epoch [26/50] | Train Loss: 0.0907 | Val Loss: 0.3631 | Val Dice: 0.8315 | Val IoU: 0.8096
# Epoch [27/50] | Train Loss: 0.0892 | Val Loss: 0.3702 | Val Dice: 0.8510 | Val IoU: 0.8292
# Epoch [28/50] | Train Loss: 0.0806 | Val Loss: 0.3578 | Val Dice: 0.8438 | Val IoU: 0.8209
# Epoch [29/50] | Train Loss: 0.0725 | Val Loss: 0.3506 | Val Dice: 0.8353 | Val IoU: 0.8114
# Epoch [30/50] | Train Loss: 0.0801 | Val Loss: 0.3476 | Val Dice: 0.8529 | Val IoU: 0.8307
# Epoch [31/50] | Train Loss: 0.0788 | Val Loss: 0.3553 | Val Dice: 0.8475 | Val IoU: 0.8261
# Epoch [32/50] | Train Loss: 0.0726 | Val Loss: 0.3582 | Val Dice: 0.8466 | Val IoU: 0.8234
# Epoch [33/50] | Train Loss: 0.0817 | Val Loss: 0.3445 | Val Dice: 0.8535 | Val IoU: 0.8320
# Epoch [34/50] | Train Loss: 0.0717 | Val Loss: 0.3470 | Val Dice: 0.8530 | Val IoU: 0.8313
# Epoch [35/50] | Train Loss: 0.0743 | Val Loss: 0.3445 | Val Dice: 0.8460 | Val IoU: 0.8242
# Epoch [36/50] | Train Loss: 0.0781 | Val Loss: 0.3441 | Val Dice: 0.8507 | Val IoU: 0.8286
# Epoch [37/50] | Train Loss: 0.0749 | Val Loss: 0.3499 | Val Dice: 0.8401 | Val IoU: 0.8154
# Epoch [38/50] | Train Loss: 0.0732 | Val Loss: 0.3502 | Val Dice: 0.8579 | Val IoU: 0.8360
#   -> 保存最优模型 (Val Dice: 0.8579)
# Epoch [39/50] | Train Loss: 0.0733 | Val Loss: 0.3566 | Val Dice: 0.8350 | Val IoU: 0.8121
# Epoch [40/50] | Train Loss: 0.0672 | Val Loss: 0.3483 | Val Dice: 0.8555 | Val IoU: 0.8333
# Epoch [41/50] | Train Loss: 0.0696 | Val Loss: 0.3483 | Val Dice: 0.8452 | Val IoU: 0.8221
# Epoch [42/50] | Train Loss: 0.0645 | Val Loss: 0.3369 | Val Dice: 0.8537 | Val IoU: 0.8312
# Epoch [43/50] | Train Loss: 0.0653 | Val Loss: 0.3549 | Val Dice: 0.8578 | Val IoU: 0.8368
# Epoch [44/50] | Train Loss: 0.0651 | Val Loss: 0.3485 | Val Dice: 0.8586 | Val IoU: 0.8367
#   -> 保存最优模型 (Val Dice: 0.8586)
# Epoch [45/50] | Train Loss: 0.0673 | Val Loss: 0.3442 | Val Dice: 0.8508 | Val IoU: 0.8288
# Epoch [46/50] | Train Loss: 0.0659 | Val Loss: 0.3416 | Val Dice: 0.8349 | Val IoU: 0.8122
# Epoch [47/50] | Train Loss: 0.0657 | Val Loss: 0.3543 | Val Dice: 0.8437 | Val IoU: 0.8221
# Epoch [48/50] | Train Loss: 0.0650 | Val Loss: 0.3500 | Val Dice: 0.8476 | Val IoU: 0.8266
# Epoch [49/50] | Train Loss: 0.0653 | Val Loss: 0.3487 | Val Dice: 0.8443 | Val IoU: 0.8229
# Epoch [50/50] | Train Loss: 0.0636 | Val Loss: 0.3479 | Val Dice: 0.8515 | Val IoU: 0.8298
# ==================================================
# 训练完成，最优验证Dice: 0.8586，模型已保存至: /kaggle/working/best_unet.pth

# %%
# %% ========================= 模块10 Inference =========================
inference_model = UNet(in_channels=1, num_classes=cfg.NUM_CLASSES, base_channels=32).to(cfg.DEVICE)
inference_model.load_state_dict(torch.load(best_ckpt_path, map_location=cfg.DEVICE))
inference_model.eval()
print(f"已加载最优模型权重: {best_ckpt_path}")
 
 
@torch.no_grad()
def predict_single(model, img, device):
    """img: (1, H, W) tensor -> pred: (H, W) numpy数组（类别索引）"""
    img = img.unsqueeze(0).to(device)
    logits = model(img)
    pred = torch.argmax(logits, dim=1).squeeze(0)
    return pred.cpu().numpy()
 
 
def get_sample_predictions(model, dataset, device, n_samples=4, seed=SEED):
    """从数据集中随机抽样n_samples个切片，返回(原图, 原始mask, 预测mask)三元组列表"""
    rng = random.Random(seed)
    indices = rng.sample(range(len(dataset)), min(n_samples, len(dataset)))
    samples = []
    for idx in indices:
        img, mask = dataset[idx]
        pred = predict_single(model, img, device)
        samples.append((img.squeeze(0).numpy(), mask.numpy(), pred))
    return samples
 
 
sample_predictions = get_sample_predictions(inference_model, test_dataset, cfg.DEVICE, n_samples=4)
print(f"已从测试集随机抽取 {len(sample_predictions)} 个样本完成推理")
# Out:
# 已加载最优模型权重: /kaggle/working/best_unet.pth
# 已从测试集随机抽取 4 个样本完成推理

# %%
# %% ========================= 模块11 Visualization =========================
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
 
MASK_CMAP = ListedColormap(["black", "yellow", "red"])  # 0=背景, 1=肾脏, 2=肿瘤
 
 
def plot_training_curves(history, save_path=None):
    epochs = list(range(1, len(history["train_loss"]) + 1))
    fig, axes = plt.subplots(2, 2, figsize=(12, 10))
 
    # 左上: Loss曲线
    axes[0, 0].plot(epochs, history["train_loss"], "r-", label="Training Loss")
    axes[0, 0].plot(epochs, history["val_loss"], "g-", label="Validation Loss")
    best_ep = int(np.argmin(history["val_loss"])) + 1
    axes[0, 0].scatter([best_ep], [history["val_loss"][best_ep - 1]], color="blue",
                        zorder=5, label=f"best epoch= {best_ep}")
    axes[0, 0].set_title("Training and Validation Loss")
    axes[0, 0].set_xlabel("Epochs")
    axes[0, 0].set_ylabel("Loss")
    axes[0, 0].legend()
 
    # 右上: Dice曲线
    axes[0, 1].plot(epochs, history["val_dice"], "g-", label="Validation Dice")
    best_ep = int(np.argmax(history["val_dice"])) + 1
    axes[0, 1].scatter([best_ep], [history["val_dice"][best_ep - 1]], color="blue",
                        zorder=5, label=f"best epoch= {best_ep}")
    axes[0, 1].set_title("Validation Dice Coefficient")
    axes[0, 1].set_xlabel("Epochs")
    axes[0, 1].set_ylabel("Dice")
    axes[0, 1].legend()
 
    # 左下: IoU曲线
    axes[1, 0].plot(epochs, history["val_iou"], "g-", label="Validation IoU")
    best_ep = int(np.argmax(history["val_iou"])) + 1
    axes[1, 0].scatter([best_ep], [history["val_iou"][best_ep - 1]], color="blue",
                        zorder=5, label=f"best epoch= {best_ep}")
    axes[1, 0].set_title("Validation IoU Coefficient")
    axes[1, 0].set_xlabel("Epochs")
    axes[1, 0].set_ylabel("IoU")
    axes[1, 0].legend()
 
    # 右下: 训练Loss单独放大查看收敛情况
    axes[1, 1].plot(epochs, history["train_loss"], "r-", label="Training Loss")
    best_ep = int(np.argmin(history["train_loss"])) + 1
    axes[1, 1].scatter([best_ep], [history["train_loss"][best_ep - 1]], color="blue",
                        zorder=5, label=f"best epoch= {best_ep}")
    axes[1, 1].set_title("Training Loss")
    axes[1, 1].set_xlabel("Epochs")
    axes[1, 1].set_ylabel("Loss")
    axes[1, 1].legend()
 
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=100, bbox_inches="tight")
    plt.show()
 
 
def plot_prediction_samples(samples, save_path=None):
    """每行: Original Image | Original Mask | Prediction，与参考模板格式一致"""
    n = len(samples)
    fig, axes = plt.subplots(n, 3, figsize=(9, 3 * n))
    if n == 1:
        axes = axes[np.newaxis, :]
 
    for i, (img, mask, pred) in enumerate(samples):
        axes[i, 0].imshow(img, cmap="gray")
        axes[i, 0].set_title("Original Image")
        axes[i, 0].axis("off")
 
        axes[i, 1].imshow(mask, cmap=MASK_CMAP, vmin=0, vmax=2)
        axes[i, 1].set_title("Original Mask")
        axes[i, 1].axis("off")
 
        axes[i, 2].imshow(pred, cmap=MASK_CMAP, vmin=0, vmax=2)
        axes[i, 2].set_title("Prediction")
        axes[i, 2].axis("off")
 
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=100, bbox_inches="tight")
    plt.show()
 
 
plot_training_curves(history, save_path=os.path.join(cfg.OUTPUT_DIR, "training_curves.png"))
plot_prediction_samples(sample_predictions, save_path=os.path.join(cfg.OUTPUT_DIR, "prediction_samples.png"))
 
print(f"最优验证Dice: {max(history['val_dice']):.4f} | 最优验证IoU: {max(history['val_iou']):.4f}")
# Out:
# 最优验证Dice: 0.8586 | 最优验证IoU: 0.8368
